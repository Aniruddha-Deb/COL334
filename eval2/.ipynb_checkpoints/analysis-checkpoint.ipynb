# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def plot_fig(protocol,n_clients,save_file_name=None):
    rtt = [f'output_{protocol}/rtt_{i}.csv' for i in range(n_clients)]
    n_pkts = 116
    sums = np.zeros(116)

    rtt_mat = [np.loadtxt(rtt[i],delimiter=',',dtype=np.int64) for i in range(n_clients)]
    
    for m in rtt_mat:
        for r in m:
            sums[r[0]] += r[1]
            
    avgs = sums/(n_clients-1)
    print(avgs.mean())
    
    plt.plot(avgs/1000)
    plt.title(f"Plot of chunk RTT's with {protocol} control layer")
    plt.grid(visible=True)
    plt.xlabel("chunk id")
    plt.ylabel("time (ms)")
    
    if (save_file_name):
        plt.savefig(save_file_name, bbox_inches='tight', dpi=150)

# %%
plot_fig("output_2",5,save_file_name="report/udp_plot.pdf")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-74-8f44c70b3b7e> in <module>
# ----> 1 plot_fig("output_udp",5,save_file_name="report/udp_plot.pdf")
#
# <ipython-input-73-7321f519a6c1> in plot_fig(protocol, n_clients, save_file_name)
#       4     sums = np.zeros(116)
#       5
# ----> 6     rtt_mat = [np.loadtxt(rtt[i],delimiter=',',dtype=np.int64) for i in range(n_clients)]
#       7
#       8     for m in rtt_mat:
#
# <ipython-input-73-7321f519a6c1> in <listcomp>(.0)
#       4     sums = np.zeros(116)
#       5
# ----> 6     rtt_mat = [np.loadtxt(rtt[i],delimiter=',',dtype=np.int64) for i in range(n_clients)]
#       7
#       8     for m in rtt_mat:
#
# ~/.pyenv/versions/3.9.0/lib/python3.9/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, like)
#    1063             fname = os_fspath(fname)
#    1064         if _is_string_like(fname):
# -> 1065             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1066             fencoding = getattr(fh, 'encoding', 'latin1')
#    1067             fh = iter(fh)
#
# ~/.pyenv/versions/3.9.0/lib/python3.9/site-packages/numpy/lib/_datasource.py in open(path, mode, destpath, encoding, newline)
#     192
#     193     ds = DataSource(destpath)
# --> 194     return ds.open(path, mode, encoding=encoding, newline=newline)
#     195
#     196
#
# ~/.pyenv/versions/3.9.0/lib/python3.9/site-packages/numpy/lib/_datasource.py in open(self, path, mode, encoding, newline)
#     529                                       encoding=encoding, newline=newline)
#     530         else:
# --> 531             raise IOError("%s not found." % path)
#     532
#     533
#
# OSError: output_output_udp/rtt_0.csv not found.

# %%
plot_fig("output_tcp",5,save_file_name="report/tcp_plot.pdf")
# Out:
# 21011.316810344826

# %%
n_clts = [5,10,50,100]
times = np.array([0.045,102,13407,216329])


plt.plot(n_clts, times/1000, marker='o')
plt.yscale('log')
plt.xticks([5,10,50,100])
plt.grid(visible=True,axis='x')
plt.title("Time taken for n clients to download A2_small_file")
plt.xlabel("no. clients")
plt.ylabel("time (s)")
plt.savefig("report/time_clients.pdf", bbox_inches='tight', dpi=150)

# %%
plot_fig("output",100)
# Out:
# 2374244.3762626257
